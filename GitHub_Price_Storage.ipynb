# %%
import time
import os

# %%
dic = {}

# %%
n=0

while True:
    time.sleep(1)
    # %store -r pa
    if pa == 'storage':            # first create a variable!
        n+=1
        if n == 1:
            for i in range(1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
            
        if n == 2:
            for i in range(1,2,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
            
        if n == 3:
            for i in range(2,3,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
                        
        if n == 4:
            for i in range(3,4,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)

                        
        if n == 5:
            for i in range(4,5,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
                    

        if n == 6:
            for i in range(5,6,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
            

        if n == 7:
            for i in range(6,7,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)

                    
        if n == 8:
            for i in range(7,8,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)

                    
        if n == 9:
            for i in range(8,9,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)
                    
               
        if n == 10:
            for i in range(9,10,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)            
                    
    
        if n == 11:
            for i in range(10,11,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(15)

                    
        if n == 12:
            for i in range(11,12,1):
                # %store -r va
                # %store -r coin_price_buy
                # %store -r coin_price_sell
                dic[f'Altcoin{i}'] = va
                dic[f'Bought_Price{i}'] = float(coin_price_buy)
                dic[f'Sold_Price{i}'] = float(coin_price_sell)
                with open("status.txt", "w") as f:
                    f.write('stopped')
                    f.flush()
                    os.fsync(f.fileno())
                    print(n)
                    pa = 'not'
                    # %store pa
                    time.sleep(10)

# %%
dic
