# %%
import pandas as pd
import numpy as np
import sqlalchemy     #for SQL Database
from sqlalchemy import create_engine
from binance import Client
from binance import BinanceSocketManager   #to interact with websocket

import asyncio
from binance import AsyncClient, BinanceSocketManager
import nest_asyncio

import time
import pymysql

import json  #to transform data from API
import websocket   #library used to connect to websocket API

import smtplib   #to send yourself an e-mail with recommendations

import datetime

import math
import os

# %%
time.sleep(10)
flag3 = True

while flag3:
    time.sleep(1)
    try:
        engine = sqlalchemy.create_engine('mysql://root:password@localhost:number/')
        # %store -r va
        time.sleep(1)
        query = "SELECT Timestamp, {} FROM {}.{}".format(va,va,va)
        # %store -r coin_price_buy    
        print('In Altcoin_Order after retrieving va and coin_price_buy')

        flag = True

        while flag:
            try:
                time.sleep(1)
                df4 = pd.read_sql(query, engine)
                bought = float(coin_price_buy)     #added testing
                df4['CumMax'] = df4[va].cummax()
                df4['stop_loss'] = df4.CumMax * 0.98
                df4['brackets'] = bought * 1.07
                if df4[df4[va] < df4['stop_loss']].last_valid_index():
                    print('The stop_loss condition was fulfilled. This is the sell price:')
                    coin_price_sell = float(df4[va].iloc[-1])
                    print(coin_price_sell)
                    # %store coin_price_sell
                    print(pd.Timestamp.now())

                    pa = 'storage'
                    # %store pa
                    pd.set_option('display.max_rows', None)
                    print(df4)
                    time.sleep(5)
                    flag3 = False
                    break        

                if df4[df4[va] > df4['brackets']].last_valid_index():
                    print('We have entered brackets.')
                    time_now = datetime.datetime.utcnow()
                    query2 = "SELECT Timestamp, {} FROM {}.{} WHERE Timestamp >= '{}'".format(va,va,va,time_now)
                    flag2 = True
                    while flag2:
                        df2 = pd.read_sql(query2,engine)
                        df2['CumMax'] = df2[va].cummax()
                        df2['sell_cond'] = df2.CumMax * 0.99
                        if df2[df2[va] < df2['sell_cond']].last_valid_index():
                            print('Inside the brackets, the sell condition was fulfilled. The sell price is:')
                            coin_price_sell = float(df2[va].iloc[-1])
                            print(coin_price_sell)
                            # %store coin_price_sell
                            print(pd.Timestamp.now())

                            pa = 'storage'
                            # %store pa
                            pd.set_option('display.max_rows', None)
                            print(df2)
                            time.sleep(5)

                            flag2 = False
                            flag = False
                            flag3 = False

            except Exception as e:
                print('The error is: ', e)
                            
                            
    except Exception as e:
        print('The error is: ', e)
